# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Data Preparation

# %%
# Load Data
df_all = pd.read_csv('state_CA-IL.csv')
df_all_backup = df_all.copy()
# Out:
# G:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,32,33,38,43,44,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.options.display.max_columns = None
df_all.head()
# Out:
#    activity_year                   lei  derived_msa-md state_code  \
# 0           2020  MV4O55SH8HO6KQSGW013           16984         IL
# 1           2020  MV4O55SH8HO6KQSGW013           28100         IL
# 2           2020  MV4O55SH8HO6KQSGW013           16984         IL
# 3           2020  MV4O55SH8HO6KQSGW013           16984         IL
# 4           2020  MV4O55SH8HO6KQSGW013           16984         IL
#
#    county_code  census_tract conforming_loan_limit  \
# 0      17043.0  1.704384e+10                     C
# 1      17091.0  1.709101e+10                     C
# 2      17043.0  1.704384e+10                     C
# 3      17031.0  1.703181e+10                     C
# 4      17031.0  1.703181e+10                     C
#
#        derived_loan_product_type             derived_dwelling_category  \
# 0  Conventional:Subordinate Lien  Single Family (1-4 Units):Site-Built
# 1        Conventional:First Lien  Single Family (1-4 Units):Site-Built
# ...

# %%
# Add apporved_status from action_taken
approve_actions = [1,2,5,6,8]
reject_actions = [3,7]
df_all['approve_status'] = np.where(df_all['action_taken'].isin(approve_actions), 1, 0)
df_all['approve_status'] = np.where(df_all['action_taken']==4, np.nan, df_all['approve_status'])

# %%
## Get datasets by aproved/reject

# Dataset without withdrawn applications
cond_appr_rej = df_all['approve_status'].isin([1,0])
df_all_appr_rej = df_all.loc[cond_appr_rej]


# # Dataset with only approved loans
# cond_appr = df_all['approve_status'] == 1
# df_all_appr = df_all.loc[cond_appr]

# # Dataset with only rejected loans
# cond_rej = df_all['approve_status'] == 0
# df_all_rej = df_all.loc[cond_rej]

## Get datasets by States
cond_ca = df_all['state_code'] == 'CA'
cond_il = df_all['state_code'] == 'IL'

# Appr/rej in in IL
df_il_appr_rej = df_all_appr_rej[cond_il]

# # Approved data in CA
# df_ca_appr = df_all_appr.loc[cond_ca]

# # Approved data in IL
# df_il_appr = df_all_appr.loc[cond_il]
# Out:
# <ipython-input-5-7afd4e867a4c>:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_il_appr_rej = df_all_appr_rej[cond_il]

# %%
# Save dataset
# df_all_appr_rej.to_csv('df_all_appr_rej.csv')
# df_all_appr.to_csv('df_all_appr.csv')
# df_all_rej.to_csv('df_all_rej.csv')
df_il_appr_rej.to_csv('df_il_appr_rej.csv')
# df_ca_appr.to_csv('df_ca_appr.csv')
# df_il_appr.to_csv('df_il_appr.csv')
